# %% [markdown]
# # 1014

# %%
x, y = input().split()
print(y, x)
# Out:
# A b
# b A

# %% [markdown]
# # 1015
# 입력: 실수 1개가 입력된다
# <br>
# 출력: 결과를 소수점 셋째 자리에서 반올림해, 소숫점 이하 둘째 자리까지 출력한다.

# %%
# 오답
x = float(input())
print(round(x, 2))
# Out:
# 1
# 1.0

# %%
# 정답
# 소숫점 이하 둘째 자리까지 출력한다는 조건을 철저하게 지켜야 한다
x = float(input())
print("%.2f" % x)
# Out:
# 1
# 1.00

# %% [markdown]
# 설명
# - 반올림: 소수점을 n 번째까지만 표현하고, 반올림을 하고 싶을 때 round를 쓴다
# <br>
# round(실수, n)
# <br>
# 그러나 입력으로 정수가 들어오면 소수점 첫 째자리까지만 보여준다.
# <br>
# <br>
# - 올림, 내림, 버림은 math 라이브러리의 ceil, floor, trunc 함수 써야함

# %% [markdown]
# ### 올림, 내림, 버림

# %%
import math

# %%
# ceil, floor, trunc 함수는 소수점 이하를 모두 버린다
math.ceil(12.2)
# Out:
# 13

# %%
math.ceil(12.22, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-a5d030dbd476> in <module>
# ----> 1 math.ceil(12.22, 1)
#
# TypeError: ceil() takes exactly one argument (2 given)

# %%
# 만약 소수점 아래에서 값을 올림하고 싶다면 아래와 같이 한다.
# 다음은 소수점 둘 째자리에서 올림하고 싶은 경우다

math.ceil(12.22 * 10) / 10
# Out:
# 12.3

# %% [markdown]
# # 1017
# 입력: int형 정수 1개
# 출력: 공백을 사이에 두고 입력받은 정수를 세 번 출력해보기

# %%
x = int(input())
print(x, x, x)
# Out:
# 3
# 3 3 3

# %% [markdown]
# # 1018
# 입력: 시와 분이 ":"으로 구분되어 입력된다
# 풀력: 입력받은 시간을 "시:분" 형식으로 출력한다.

# %%
hour, minute = input().split(":")
print("%s:%s" % hour, minute)
# Out:
# 3:16
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d0843860922d> in <module>
#       1 hour, minute = input().split(":")
# ----> 2 print("%s:%s" % hour, minute)
#
# TypeError: not enough arguments for format string

# %% [markdown]
# ### 정답 1

# %%
hour, minute = input().split(":")
print("%s:%s" % (hour, minute))
# Out:
# 3:16
# 3:16

# %% [markdown]
# ### 정답 2

# %%
hour, minute = input().split(":")
print("{hour}:{minute}".format(hour=hour, minute=minute))
# Out:
# 3:16
# 3:16

# %% [markdown]
# # 1019
# 입력: 연, 월, 일이 "."으로 구분되어 입력된다.
#
# 출력: 입력받은 연, 월, 일을 yyyy.mm.dd 형식으로 출력한다.

# %%
y, m, d = input().split(".")
print("%04s.%02s.%02s" % (y, m, d))
# Out:
# 2013.8.5
# 2013. 8. 5

# %%
y, m, d = list(map(int, input().split(".")))
print("%04d.%02d.%02d" % (y, m, d))
# Out:
# 2013.8.5
# 2013.08.05

# %%
print("%14d.%12d.%12d" % (y, m, d))
# 공백을 0대신 1로 채울수는 없나보다 
# 14d가 1로 채우라는 말로 인식된 게 아니라 14개의 자리를 유지하라는 것으로 인식된 듯
# Out:
#           2013.           8.           5

# %% [markdown]
# # 1020
# 입력: 주민번호 앞 6자리와 뒷 7자리가 '-'로 구분되어 입력된다.
#
# 출력: '-'를 제외한 주민번호 13자리를 모두 붙여 출력한다

# %%
front, back = input().split('-')
print(front+back)
# Out:
# 000907-1121112
# 0009071121112

# %% [markdown]
# # 1021
# 입력: 한 단어가 입력된다.
#
# 출력: 입력된 단어를 그대로 출력한다

# %%
x = input()
print(x)
# Out:
# informatics
# informatics

# %% [markdown]
# # 1022
# 입력: 공백이 포함되어 이는 한 문장이 입력된다. 엔터로 끝나며 최대 길이는 2000문자를 넘지 않는다.
#
# 출력: 입력된 문장을 그대로 출력한다.

# %%
x = input() 
print(x)
# Out:
# Programming is very fun
# Programming is very fun

# %% [markdown]
# # 1023
# 입력: 실수 1개가 입력된다. 단 절댓값이 10000을 넘지 않으며, 소수점 이하 자릿수는 최대 6자리이고 0이 아닌 숫자로 시작한다.
#
# 출력: 첫 번째 줄에 정수 부분을, 두 번째 줄에 실수 부분을 출력한다.

# %%
i, f = input().split(".")
print("%s\n%s" % (i, f))
# Out:
# 1.41
# 1
# 41

# %% [markdown]
# # 1024
# 입력: 영어 단어 하나
#
# 출력: 단어의 문자 하나씩 나누어, 한줄에 한 개씩, ''로 묶어서 출력한다.

# %%
word = input()
for char in word:
    print('\'%s\'' % char)
# Out:
# Boy
# 'B'
# 'o'
# 'y'

# %% [markdown]
# # 1025
# 입력: 다섯자리로 이루어진 한 개의 정수를 입력받는다.
# 10,000 <= 입력받는 수 <= 99,999
#
# 출력: 각 자리의 숫자를 분리해서 한 줄에 하나씩 [] 속에 넣어 출력한다

# %%
## 오답

num = input()

for i in range(len(num)):
    digit = len(num) - i - 1
    # print(int(num[i]) * 10**digit)
    print('[%d]' % int(num[i]) * 10**digit)
# Out:
# 75254
# ...

# %%
## 정답
# 교훈: 연산자 우선순위를 잘 지켜야한다

num = input()

for i in range(len(num)):
    digit = len(num) - i - 1
    # print(int(num[i]) * 10**digit)
    print('[%d]' % (int(num[i]) * 10**digit))
# Out:
# 75254
# [70000]
# [5000]
# [200]
# [50]
# [4]

# %% [markdown]
# # 1026
# 입력: 시 분 초가 시:분:초 형식으로 입력된다.
#
# 출력: 분만 출력한다.

# %%
# 오답
h, m, s = input().split(":")
print(m)
# Out:
# 17:06:98
# 06

# %%
# 정답
h, m, s = input().split(":")
print(int(m))
# Out:
# 17:06:98
# 6

# %% [markdown]
# # 1027
# 입력: 년월일이 '.'으로 구분되어 입력된다.
#
# 출력: 년월일은 일월년으로 바꾸어 '-'로 구분해 출력한다.

# %%
# 오답: 

y, m, d = input().split(".")
print((d, m, y).join('-'))

# join의 사용법을 제대로 알지 못했다.
# "특정문자열".join(리스트)
# Out:
# 2014.07.15
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f23db4486b7a> in <module>
#       2
#       3 y, m, d = input().split(".")
# ----> 4 print((d, m, y).join('-'))
#       5
#       6 # join의 사용법을 제대로 알지 못했다.
#
# AttributeError: 'tuple' object has no attribute 'join'

# %%
# 정답

lst = input().split(".")
# lst = list(reversed(lst))
lst.reverse()
print('-'.join(lst))
# Out:
# 2014.07.15
# 15-07-2014
